# %%
import numpy as np
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Convolution2D, MaxPooling2D
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import image
from IPython import display

# %%
img_c_t = []
test_c = "15812904_t1_tse_sag_7.jpg"   #test image for control group
#image preprocessing...
img_c = image.load_img(test_c,target_size=(80,60,3))
img = image.img_to_array(img_c)
norm = img/255
img_c_t.append(norm)
img_c_t = np.array(img_c_t)
display.Image(test_c)

# %%
img_o_t = []
test_image_osteo = "035516(119).jpg" #test image for osteoporosis group
#image preprocessing...
img_o = image.load_img(test_image_osteo,target_size=(80,60,3))
img = image.img_to_array(img_o)
norm = img/255
img_o_t.append(norm)
img_o_t = np.array(img_o_t)
display.Image(test_image_osteo)

# %%
# Loading model and weights...
loaded_model = keras.models.load_model("UNIMODAL.h5") 
# compile and display model summary...
loaded_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
loaded_model.summary()
# Out:
# Model: "uni"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  img (InputLayer)               [(None, 80, 60, 3)]  0           []
#
#  a1 (Conv2D)                    (None, 78, 58, 32)   896         ['img[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 78, 58, 32)  128         ['a1[0][0]']
#  ormalization)
#
#  max_pooling2d_10 (MaxPooling2D  (None, 39, 29, 32)  0           ['batch_normalization_20[0][0]']
#  )
#
#  b1 (Conv2D)                    (None, 40, 30, 32)   2432        ['img[0][0]']
#
#  a2 (Conv2D)                    (None, 37, 27, 32)   9248        ['max_pooling2d_10[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 40, 30, 32)  128         ['b1[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 37, 27, 32)  128         ['a2[0][0]']
#  ormalization)
#
#  b2 (Conv2D)                    (None, 18, 13, 32)   25632       ['batch_normalization_22[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 18, 13, 32)  0           ['batch_normalization_21[0][0]']
#  )
#
#  batch_normalization_23 (BatchN  (None, 18, 13, 32)  128         ['b2[0][0]']
#  ormalization)
#
#  add_layer (Add)                (None, 18, 13, 32)   0           ['max_pooling2d_11[0][0]',
#                                                                   'batch_normalization_23[0][0]']
#
#  add_out (Conv2D)               (None, 18, 13, 64)   51264       ['add_layer[0][0]']
#
#  flatten_5 (Flatten)            (None, 14976)        0           ['add_out[0][0]']
#
#  dense_15 (Dense)               (None, 32)           479264      ['flatten_5[0][0]']
#
#  dense_16 (Dense)               (None, 16)           528         ['dense_15[0][0]']
#
#  dense_17 (Dense)               (None, 1)            17          ['dense_16[0][0]']
#
# ==================================================================================================
# Total params: 569,793
# Trainable params: 569,537
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %%
#Predicting test image (osteporosis...)
y_pred = loaded_model.predict(img_o_t)   
print('Osteoporosis:', y_pred) if np.round(y_pred) == 1 else print('Healthy:', y_pred)
# Out:
# 1/1 [==============================] - 0s 154ms/step
# Osteoporosis: [[0.99999934]]

# %%
#Predicting test image (control...)
y_pred = loaded_model.predict(img_c_t)   
print('Osteoporosis:', y_pred) if np.round(y_pred) == 1 else print('Healthy:', y_pred)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# Healthy: [[0.00022027]]
